# %% [markdown]
# ### **Chú ý:** Thiết lập những cài đặt Facebook sau để tránh bị lỗi
#
# 1. Tắt chức năng tự động phát video.
# 2. Tắt chức năng tự động dịch từ tiếng Việt.

# %%
# !python main.py \
    --chromedriver=/home/ptdat/Downloads/chromedriver-linux64/chromedriver \
    --crawler=page_crawler \
    --user=user1 \
    --crawler-dir=./data/ \
    --sleep-weibull-lambda=10 \
    --max-loading-wait=90 \
    --cookies-dir=./cookies/ \
    --secrets-json=./secrets.json \
    --error-screenshot-dir=./error-screenshots/ \
    --max-error-trials=0
# Out:
# [Page Crawler][INFO][11-03 23:48:41]: Initializing...
# [Page Crawler][INFO][11-03 23:48:42]: Driver started
# [Page Crawler][INFO][11-03 23:48:42]: Ensuring user logging in
# [Page Crawler][INFO][11-03 23:48:42]: Found user's credentials cached as cookies
# [Page Crawler][INFO][11-03 23:48:44]: Saved/Refreshed cookies
# [Page Crawler][INFO][11-03 23:48:44]: Matched as URL for navigation: https://www.facebook.com/naman.benhvienthammy
# [Page Crawler][INFO][11-03 23:48:49]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][11-03 23:48:49]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][11-03 23:48:49]: Matched as URL for parsing: https://www.facebook.com/naman.benhvienthammy
# [Page Crawler][INFO][11-03 23:48:52]: Opened new tab to https://www.facebook.com/naman.benhvienthammy
# [Page Crawler][INFO][11-03 23:49:43]: Opened new tab to https://www.facebook.com/455840687524538
# [Page Crawler][INFO][11-03 23:50:00]: Opened new tab to https://www.facebook.com/981807236881751
# [Page Crawler][INFO][11-03 23:50:16]: Opened new tab to https://www.facebook.com/1710665383128181
# [Page Crawler][INFO][11-03 23:50:43]: Opened new tab to https://www.facebook.com/1435468637827082
# [Page Crawler][INFO][11-03 23:51:39]: Opened new tab to https://www.facebook.com/29033750802904989
# [Page Crawler][INFO][11-03 23:52:26]: Opened new tab to https://www.facebook.com/9697252933640096
# [Page Crawler][INFO][11-03 23:52:44]: Opened new tab to https://www.facebook.com/1373628437128030
# [Page Crawler][INFO][11-03 23:54:11]: Opened new tab to https://www.facebook.com/1878995529588163
# RAM Usage (GB):  47%|▍| 7.15/15.33 [05:56<06:47, 49.86s/it, # Scraped posts: 13]

# %% [markdown]
# ### Trong trường hợp Facebook yêu cầu đăng nhập lại
#
# Chạy cell code dưới đây, một cửa sổ Chrome sẽ hiện ra. Hãy đăng nhập Facebook bằng cửa sổ Chrome này.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from utils.cookies import Cookies

driver_service = Service("/home/ptdat/Downloads/chromedriver-linux64/chromedriver")
driver_options = webdriver.ChromeOptions()
cookies = Cookies("user1")

chrome = webdriver.Chrome(service=driver_service, options=driver_options)
chrome.get("https://facebook.com")

# %% [markdown]
# Sau khi hoàn thành đăng nhập (truy cập được news feed của tài khoản Facebook). Hãy chạy cell dưới đây để lưu cookies và giữ phiên đăng nhập cho những lần sau.

# %%
cookies.save(chrome.get_cookies())

# %% [markdown]
# Tại bước này có thể tắt cửa sổ Chrome đi được rùi.
