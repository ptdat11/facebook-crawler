# %%
# !python main.py \
    --chromedriver=/home/ptdat/.wdm/drivers/chromedriver/linux64/130.0.6723.58/chromedriver-linux64/chromedriver \
    --crawler=page_crawler \
    --user=user1 \
    --crawler-dir=./data/ \
    --sleep-weibull-lambda=7 \
    --max-loading-wait=90 \
    --cookies-dir=./cookies/ \
    --secrets-json=./secrets.json \
    --error-screenshot-dir=./error-screenshots/ \
    --max-error-trials=0
# Out:
# [Page Crawler][INFO][05-01 21:19:00]: Initializing...
# [Page Crawler][INFO][05-01 21:19:02]: Driver started
# [Page Crawler][INFO][05-01 21:19:02]: Ensuring user logging in
# [Page Crawler][INFO][05-01 21:19:02]: Found user's credentials cached as cookies
# [Page Crawler][INFO][05-01 21:19:03]: Saved/Refreshed cookies
# [Page Crawler][INFO][05-01 21:19:03]: Matched as URL for navigation: https://www.facebook.com/100064250406170
# [Page Crawler][INFO][05-01 21:19:07]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][05-01 21:19:07]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][05-01 21:19:07]: Matched as URL for parsing: https://www.facebook.com/100064250406170
# [Page Crawler][INFO][05-01 21:19:09]: Opened new tab to https://www.facebook.com/100064250406170
# RAM Usage (GB):  37%|██████▉            | 5.61/15.33 [00:00<00:00, 75659.31it/s][Page Crawler][INFO][05-01 21:19:11]: Found 1st post as story, skipping...
# [Page Crawler][INFO][05-01 21:19:12]: Found 2nd post as story, skipping...
# [Page Crawler][INFO][05-01 21:19:13]: Found 3rd post as story, skipping...
# RAM Usage (GB):  37%|████████              | 5.61/15.33 [00:10<00:17,  1.83s/it][Page Crawler][INFO][05-01 21:19:21]: Found 1st post as story, skipping...
# [Page Crawler][INFO][05-01 21:19:22]: Found 2nd post as story, skipping...
# [Page Crawler][INFO][05-01 21:19:23]: Found 3rd post as story, skipping...
# [Page Crawler][INFO][05-01 21:19:24]: Found 4th post as story, skipping...
# [Page Crawler][INFO][05-01 21:19:25]: Found 5th post as story, skipping...
# [Page Crawler][INFO][05-01 21:19:26]: Found 6th post as story, skipping...
# ^C
# RAM Usage (GB):  37%|████████              | 5.61/15.33 [00:22<00:38,  3.94s/it]
# [Page Crawler][ERROR][05-01 21:19:31]: Restore https://www.facebook.com/100064250406170 to queue due to error:
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/base_crawler.py", line 230, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/base_crawler.py", line 282, in _handle_parse_url
#     for data in self.parse():
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 183, in parse
#     self.sleep()
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/base_crawler.py", line 130, in sleep
#     time.sleep(sleep_second)
# KeyboardInterrupt
#
# [Page Crawler][ERROR][05-01 21:19:31]: Closing driver due to an error occured...

# %%
from bs4 import BeautifulSoup

BeautifulSoup("")
