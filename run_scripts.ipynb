# %% [markdown]
# ### **Chú ý:** Thiết lập những cài đặt Facebook sau để tránh bị lỗi
#
# 1. Tắt chức năng tự động phát video.
# 2. Tắt chức năng tự động dịch từ tiếng Việt.

# %%
# !python main.py \
    --chromedriver=/home/ptdat/Downloads/chromedriver-linux64/chromedriver \
    --crawler=page_crawler \
    --user=user1 \
    --crawler-dir=./data/ \
    --sleep-weibull-lambda=10 \
    --max-loading-wait=90 \
    --cookies-dir=./cookies/ \
    --secrets-json=./secrets.json \
    --error-screenshot-dir=./error-screenshots/ \
    --max-error-trials=0 \
    --headless
# Out:
# [Page Crawler][INFO][13-03 08:29:43]: Initializing...
# [Page Crawler][INFO][13-03 08:29:44]: Driver started
# [Page Crawler][INFO][13-03 08:29:44]: Ensuring user logging in
# [Page Crawler][INFO][13-03 08:29:44]: Found user's credentials cached as cookies
# [Page Crawler][INFO][13-03 08:29:46]: Saved/Refreshed cookies
# [Page Crawler][INFO][13-03 08:29:46]: Matched as URL for navigation: https://www.facebook.com/naman.benhvienthammy
# [Page Crawler][INFO][13-03 08:29:49]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][13-03 08:29:49]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][13-03 08:29:49]: Matched as URL for parsing: https://www.facebook.com/naman.benhvienthammy
# [Page Crawler][INFO][13-03 08:29:51]: Opened new tab to https://www.facebook.com/naman.benhvienthammy
# [Page Crawler][INFO][13-03 08:29:58]: Opened Chrome driver tab to https://www.facebook.com/1817215835788353
# [Page Crawler][INFO][13-03 08:31:25]: Opened Chrome driver tab to https://www.facebook.com/527144423341697
# [Page Crawler][INFO][13-03 08:34:02]: Opened Chrome driver tab to https://www.facebook.com/455840687524538
# [Page Crawler][INFO][13-03 08:34:20]: Opened Chrome driver tab to https://www.facebook.com/981807236881751
# [Page Crawler][INFO][13-03 08:34:38]: Opened Chrome driver tab to https://www.facebook.com/1710665383128181
# [Page Crawler][INFO][13-03 08:35:03]: Opened Chrome driver tab to https://www.facebook.com/1435468637827082
# [Page Crawler][INFO][13-03 08:36:03]: Opened Chrome driver tab to https://www.facebook.com/29033750802904989
# [Page Crawler][INFO][13-03 08:36:58]: Opened Chrome driver tab to https://www.facebook.com/9697252933640096
# [Page Crawler][INFO][13-03 08:37:12]: Opened Chrome driver tab to https://www.facebook.com/1373628437128030
# [Page Crawler][INFO][13-03 08:38:43]: Opened Chrome driver tab to https://www.facebook.com/1878995529588163
# [Page Crawler][INFO][13-03 08:40:48]: Opened Chrome driver tab to https://www.facebook.com/636985342610519
# [Page Crawler][INFO][13-03 08:41:06]: Opened Chrome driver tab to https://www.facebook.com/1129024568696805
# RAM Usage (GB):  45%|▍| 6.96/15.33 [11:26<13:45, 98.65s/it, # Scraped posts: 23]

# %% [markdown]
# ### Trong trường hợp Facebook yêu cầu đăng nhập lại
#
# Chạy cell code dưới đây, một cửa sổ Chrome sẽ hiện ra. Hãy đăng nhập Facebook bằng cửa sổ Chrome này.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from utils.cookies import Cookies

driver_service = Service("/home/ptdat/Downloads/chromedriver-linux64/chromedriver")
driver_options = webdriver.ChromeOptions()
cookies = Cookies("user1")

chrome = webdriver.Chrome(service=driver_service, options=driver_options)
chrome.get("https://facebook.com")

# %% [markdown]
# Sau khi hoàn thành đăng nhập (truy cập được news feed của tài khoản Facebook). Hãy chạy cell dưới đây để lưu cookies và giữ phiên đăng nhập cho những lần sau.

# %%
cookies.save(chrome.get_cookies())

# %% [markdown]
# Tại bước này có thể tắt cửa sổ Chrome đi được rùi.
