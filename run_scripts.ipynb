# %% [markdown]
# ### **Chú ý:** Thiết lập những cài đặt Facebook sau để tránh bị lỗi
#
# 1. Tắt chức năng tự động phát video.
# 2. Tắt chức năng tự động dịch từ tiếng Việt.

# %%
# !python main.py \
    --chromedriver=/home/ptdat/Downloads/chromedriver-linux64/chromedriver \
    --crawler=page_crawler \
    --user=user1 \
    --crawler-dir=./data/ \
    --sleep-weibull-lambda=10 \
    --max-loading-wait=90 \
    --cookies-dir=./cookies/ \
    --secrets-json=./secrets.json \
    --error-screenshot-dir=./error-screenshots/ \
    --max-error-trials=0 \
    # --headless
# Out:
# [Page Crawler][INFO][13-03 22:28:45]: Initializing...
# [Page Crawler][INFO][13-03 22:28:46]: Driver started
# [Page Crawler][INFO][13-03 22:28:46]: Ensuring user logging in
# [Page Crawler][INFO][13-03 22:28:46]: Found user's credentials cached as cookies
# [Page Crawler][INFO][13-03 22:28:47]: Saved/Refreshed cookies
# [Page Crawler][INFO][13-03 22:28:47]: Matched as URL for navigation: https://www.facebook.com/bvquoctethaodien
# [Page Crawler][INFO][13-03 22:28:50]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][13-03 22:28:50]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][13-03 22:28:50]: Matched as URL for parsing: https://www.facebook.com/bvquoctethaodien
# [Page Crawler][INFO][13-03 22:28:52]: Opened new tab to https://www.facebook.com/bvquoctethaodien
# [Page Crawler][INFO][13-03 22:28:56]: Opened new Chrome driver to https://www.facebook.com/1620118898631822
# [Page Crawler][INFO][13-03 22:29:10]: Opened new Chrome driver to https://www.facebook.com/928036396076083
# [Page Crawler][INFO][13-03 22:30:50]: Opened new Chrome driver to https://www.facebook.com/611461178383650
# [Page Crawler][INFO][13-03 22:31:47]: Opened new Chrome driver to https://www.facebook.com/1352132622469680
# [Page Crawler][INFO][13-03 22:32:22]: Opened new Chrome driver to https://www.facebook.com/1348765049494589
# [Page Crawler][INFO][13-03 22:32:38]: Opened new Chrome driver to https://www.facebook.com/1147705870370790
# [Page Crawler][INFO][13-03 22:32:52]: Opened new Chrome driver to https://www.facebook.com/1140632487337944
# [Page Crawler][INFO][13-03 22:33:38]: Opened new Chrome driver to https://www.facebook.com/1146619316958759
# [Page Crawler][INFO][13-03 22:33:51]: Opened new Chrome driver to https://www.facebook.com/1107072241191671
# [Page Crawler][INFO][13-03 22:34:39]: Opened new Chrome driver to https://www.facebook.com/628815066558668
# [Page Crawler][INFO][13-03 22:36:30]: Opened new Chrome driver to https://www.facebook.com/1793106084815899
# [Page Crawler][INFO][13-03 22:36:41]: Opened new Chrome driver to https://www.facebook.com/636342695620704
# [Page Crawler][INFO][13-03 22:37:25]: Opened new Chrome driver to https://www.facebook.com/1150616733165750
# [Page Crawler][INFO][13-03 22:37:40]: Opened new Chrome driver to https://www.facebook.com/621716483683448
# [Page Crawler][INFO][13-03 22:38:19]: Opened new Chrome driver to https://www.facebook.com/1154301702733763
# [Page Crawler][INFO][13-03 22:40:46]: Opened new Chrome driver to https://www.facebook.com/614836524355181
# [Page Crawler][INFO][13-03 22:41:52]: Opened new Chrome driver to https://www.facebook.com/961170099308738
# [Page Crawler][INFO][13-03 22:42:31]: Opened new Chrome driver to https://www.facebook.com/964568605733301
# [Page Crawler][INFO][13-03 22:42:45]: Opened new Chrome driver to https://www.facebook.com/1579907292641477
# [Page Crawler][INFO][13-03 22:42:59]: Opened new Chrome driver to https://www.facebook.com/3835952913384595
# [Page Crawler][INFO][13-03 22:43:35]: Opened new Chrome driver to https://www.facebook.com/587153637605776
# [Page Crawler][INFO][13-03 22:44:10]: Opened new Chrome driver to https://www.facebook.com/1090169392843771
# [Page Crawler][INFO][13-03 22:44:48]: Opened new Chrome driver to https://www.facebook.com/1954200471771104
# [Page Crawler][INFO][13-03 22:45:01]: Opened new Chrome driver to https://www.facebook.com/951515603527749
# [Page Crawler][INFO][13-03 22:47:12]: Opened new Chrome driver to https://www.facebook.com/3231807653629119
# [Page Crawler][INFO][13-03 22:49:00]: Opened new Chrome driver to https://www.facebook.com/1227513678548636
# [Page Crawler][INFO][13-03 22:50:58]: Opened new Chrome driver to https://www.facebook.com/1281531796493144
# [Page Crawler][INFO][13-03 22:51:40]: Opened new Chrome driver to https://www.facebook.com/1846512082755324
# [Page Crawler][WARNING][13-03 22:53:43]: Skipping 60th post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 172, in parse
#     post = self.parse_post(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 311, in parse_post
#     visual_urls = self.get_visual_content(visual_content_div)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 391, in get_visual_content
#     first_content_id = self.get_visual_content_id(self.chrome.current_url, "img" if first_is_image else "video")
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 326, in get_visual_content_id
#     return re.search(r"photo/?\?fbid=((\d)+)", url).group(1)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 22:54:02]: Opened new Chrome driver to https://www.facebook.com/937271861679353
# [Page Crawler][INFO][13-03 22:54:23]: Opened new Chrome driver to https://www.facebook.com/2357292321317885
# [Page Crawler][WARNING][13-03 22:54:23]: Skipping 62nd post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 223, in parse_reel
#     reel_video_urls = get_video_url_from_source(new_chrome.page_source)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/utils/parsing.py", line 52, in get_video_url_from_source
#     video_url = re.search(r'"base_url":"([^"]+)"', source).group(1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 22:54:43]: Opened new Chrome driver to https://www.facebook.com/878815544467777
# [Page Crawler][INFO][13-03 22:56:15]: Opened new Chrome driver to https://www.facebook.com/752870647057899
# [Page Crawler][WARNING][13-03 22:56:16]: Skipping 67th post: NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 235, in parse_reel
#     caption_div = new_chrome.find_element(By.XPATH, "//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 1244, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
#
# [Page Crawler][INFO][13-03 22:56:55]: Opened new Chrome driver to https://www.facebook.com/906887994845283
# [Page Crawler][INFO][13-03 22:57:07]: Opened new Chrome driver to https://www.facebook.com/1119414546209008
# [Page Crawler][INFO][13-03 22:57:20]: Opened new Chrome driver to https://www.facebook.com/597955456028097
# [Page Crawler][INFO][13-03 22:58:49]: Opened new Chrome driver to https://www.facebook.com/537254832431459
# [Page Crawler][INFO][13-03 22:59:03]: Opened new Chrome driver to https://www.facebook.com/2841289442706226
# [Page Crawler][INFO][13-03 22:59:20]: Opened new Chrome driver to https://www.facebook.com/1938241639989771
# [Page Crawler][INFO][13-03 22:59:35]: Opened new Chrome driver to https://www.facebook.com/916453046690644
# [Page Crawler][INFO][13-03 23:00:18]: Opened new Chrome driver to https://www.facebook.com/583667110692915
# [Page Crawler][INFO][13-03 23:01:28]: Opened new Chrome driver to https://www.facebook.com/435530029590172
# [Page Crawler][INFO][13-03 23:02:08]: Opened new Chrome driver to https://www.facebook.com/1329045651600131
# [Page Crawler][INFO][13-03 23:02:21]: Opened new Chrome driver to https://www.facebook.com/1998201587364208
# [Page Crawler][INFO][13-03 23:03:39]: Opened new Chrome driver to https://www.facebook.com/8692122884188886
# [Page Crawler][INFO][13-03 23:04:23]: Opened new Chrome driver to https://www.facebook.com/414221941742585
# [Page Crawler][INFO][13-03 23:05:10]: Opened new Chrome driver to https://www.facebook.com/1078691453806460
# [Page Crawler][INFO][13-03 23:05:54]: Opened new Chrome driver to https://www.facebook.com/901312901632244
# [Page Crawler][WARNING][13-03 23:05:54]: Skipping 93rd post: NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 235, in parse_reel
#     caption_div = new_chrome.find_element(By.XPATH, "//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 1244, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
#
# [Page Crawler][INFO][13-03 23:06:08]: Opened new Chrome driver to https://www.facebook.com/873049391683952
# [Page Crawler][INFO][13-03 23:06:23]: Opened new Chrome driver to https://www.facebook.com/965561362077082
# [Page Crawler][INFO][13-03 23:06:39]: Opened new Chrome driver to https://www.facebook.com/1218787119354757
# [Page Crawler][INFO][13-03 23:06:54]: Opened new Chrome driver to https://www.facebook.com/974990617976470
# [Page Crawler][INFO][13-03 23:07:08]: Opened new Chrome driver to https://www.facebook.com/1087125745670492
# [Page Crawler][INFO][13-03 23:07:33]: Opened new Chrome driver to https://www.facebook.com/1438229913537921
# [Page Crawler][INFO][13-03 23:08:37]: Opened new Chrome driver to https://www.facebook.com/1270736127444498
# [Page Crawler][INFO][13-03 23:08:53]: Opened new Chrome driver to https://www.facebook.com/487073957646158
# [Page Crawler][INFO][13-03 23:09:37]: Opened new Chrome driver to https://www.facebook.com/1730912857764440
# [Page Crawler][INFO][13-03 23:09:52]: Opened new Chrome driver to https://www.facebook.com/1379844903401735
# [Page Crawler][INFO][13-03 23:11:14]: Opened new Chrome driver to https://www.facebook.com/1179289006485060
# [Page Crawler][INFO][13-03 23:11:28]: Opened new Chrome driver to https://www.facebook.com/574949674872107
# [Page Crawler][INFO][13-03 23:12:11]: Opened new Chrome driver to https://www.facebook.com/555544210290632
# [Page Crawler][INFO][13-03 23:12:25]: Opened new Chrome driver to https://www.facebook.com/551589630573142
# [Page Crawler][INFO][13-03 23:13:08]: Opened new Chrome driver to https://www.facebook.com/552560487278322
# [Page Crawler][WARNING][13-03 23:13:09]: Skipping 114th post: NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 235, in parse_reel
#     caption_div = new_chrome.find_element(By.XPATH, "//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 1244, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
#
# [Page Crawler][INFO][13-03 23:13:35]: Opened new Chrome driver to https://www.facebook.com/1603117403618263
# [Page Crawler][INFO][13-03 23:13:55]: Opened new Chrome driver to https://www.facebook.com/908640307981063
# [Page Crawler][INFO][13-03 23:15:10]: Opened new Chrome driver to https://www.facebook.com/1305930627481721
# [Page Crawler][INFO][13-03 23:15:25]: Opened new Chrome driver to https://www.facebook.com/531495049400421
# [Page Crawler][INFO][13-03 23:15:42]: Opened new Chrome driver to https://www.facebook.com/491287790537306
# [Page Crawler][WARNING][13-03 23:15:42]: Skipping 121st post: NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 235, in parse_reel
#     caption_div = new_chrome.find_element(By.XPATH, "//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 1244, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
#
# [Page Crawler][INFO][13-03 23:15:58]: Opened new Chrome driver to https://www.facebook.com/828822182390075
# [Page Crawler][WARNING][13-03 23:15:59]: Skipping 122nd post: NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 235, in parse_reel
#     caption_div = new_chrome.find_element(By.XPATH, "//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 1244, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
#
# [Page Crawler][INFO][13-03 23:19:14]: Opened new Chrome driver to https://www.facebook.com/2394002460795292
# [Page Crawler][INFO][13-03 23:19:30]: Opened new Chrome driver to https://www.facebook.com/383336374455541
# [Page Crawler][WARNING][13-03 23:19:30]: Skipping 130th post: NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 235, in parse_reel
#     caption_div = new_chrome.find_element(By.XPATH, "//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 1244, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[starts-with(@class, 'xyamay9 x1pi30zi x1swvt13 xjkvuk6')]/span/div"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5ab90435c46a <unknown>
# #1 0x5ab903e15ed0 <unknown>
# #2 0x5ab903e67935 <unknown>
# #3 0x5ab903e67b61 <unknown>
# #4 0x5ab903eb69d4 <unknown>
# #5 0x5ab903e8d88d <unknown>
# #6 0x5ab903eb3ceb <unknown>
# #7 0x5ab903e8d633 <unknown>
# #8 0x5ab903e591be <unknown>
# #9 0x5ab903e5a981 <unknown>
# #10 0x5ab90432286b <unknown>
# #11 0x5ab90432673c <unknown>
# #12 0x5ab904309f12 <unknown>
# #13 0x5ab9043272b4 <unknown>
# #14 0x5ab9042ee0af <unknown>
# #15 0x5ab90434aad8 <unknown>
# #16 0x5ab90434acb6 <unknown>
# #17 0x5ab90435b2e6 <unknown>
# #18 0x7345a689caa4 <unknown>
# #19 0x7345a6929c3c <unknown>
#
#
# [Page Crawler][INFO][13-03 23:19:45]: Opened new Chrome driver to https://www.facebook.com/903084838326053
# [Page Crawler][INFO][13-03 23:20:02]: Opened new Chrome driver to https://www.facebook.com/1224537598898100
# [Page Crawler][INFO][13-03 23:22:02]: Opened new Chrome driver to https://www.facebook.com/1554545998480799
# [Page Crawler][INFO][13-03 23:22:20]: Opened new Chrome driver to https://www.facebook.com/1551046772146718
# [Page Crawler][INFO][13-03 23:22:35]: Opened new Chrome driver to https://www.facebook.com/495153706669794
# [Page Crawler][INFO][13-03 23:24:21]: Opened new Chrome driver to https://www.facebook.com/1018113076582938
# [Page Crawler][INFO][13-03 23:24:37]: Opened new Chrome driver to https://www.facebook.com/1277966603201201
# [Page Crawler][INFO][13-03 23:25:24]: Opened new Chrome driver to https://www.facebook.com/1143730583577383
# [Page Crawler][WARNING][13-03 23:29:03]: Skipping 145th post: NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//img"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5fd7f37bb46a <unknown>
# #1 0x5fd7f3274ed0 <unknown>
# #2 0x5fd7f32c6935 <unknown>
# #3 0x5fd7f32c6b61 <unknown>
# #4 0x5fd7f32ba446 <unknown>
# #5 0x5fd7f32ec88d <unknown>
# #6 0x5fd7f32ba33a <unknown>
# #7 0x5fd7f32eca2e <unknown>
# #8 0x5fd7f3312ceb <unknown>
# #9 0x5fd7f32ec633 <unknown>
# #10 0x5fd7f32b81be <unknown>
# #11 0x5fd7f32b9981 <unknown>
# #12 0x5fd7f378186b <unknown>
# #13 0x5fd7f378573c <unknown>
# #14 0x5fd7f3768f12 <unknown>
# #15 0x5fd7f37862b4 <unknown>
# #16 0x5fd7f374d0af <unknown>
# #17 0x5fd7f37a9ad8 <unknown>
# #18 0x5fd7f37a9cb6 <unknown>
# #19 0x5fd7f37ba2e6 <unknown>
# #20 0x770bacc9caa4 <unknown>
# #21 0x770bacd29c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 172, in parse
#     post = self.parse_post(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 311, in parse_post
#     visual_urls = self.get_visual_content(visual_content_div)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 372, in get_visual_content
#     first_content = visual_content_div.find_element(By.XPATH, ".//img")
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 735, in find_element
#     return self._execute(Command.FIND_CHILD_ELEMENT,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 710, in _execute
#     return self._parent.execute(command, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//img"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5fd7f37bb46a <unknown>
# #1 0x5fd7f3274ed0 <unknown>
# #2 0x5fd7f32c6935 <unknown>
# #3 0x5fd7f32c6b61 <unknown>
# #4 0x5fd7f32ba446 <unknown>
# #5 0x5fd7f32ec88d <unknown>
# #6 0x5fd7f32ba33a <unknown>
# #7 0x5fd7f32eca2e <unknown>
# #8 0x5fd7f3312ceb <unknown>
# #9 0x5fd7f32ec633 <unknown>
# #10 0x5fd7f32b81be <unknown>
# #11 0x5fd7f32b9981 <unknown>
# #12 0x5fd7f378186b <unknown>
# #13 0x5fd7f378573c <unknown>
# #14 0x5fd7f3768f12 <unknown>
# #15 0x5fd7f37862b4 <unknown>
# #16 0x5fd7f374d0af <unknown>
# #17 0x5fd7f37a9ad8 <unknown>
# #18 0x5fd7f37a9cb6 <unknown>
# #19 0x5fd7f37ba2e6 <unknown>
# #20 0x770bacc9caa4 <unknown>
# #21 0x770bacd29c3c <unknown>
#
#
# [Page Crawler][INFO][13-03 23:29:19]: Opened new Chrome driver to https://www.facebook.com/433101966359389
# [Page Crawler][INFO][13-03 23:31:31]: Opened new Chrome driver to https://www.facebook.com/1172677714076459
# [Page Crawler][INFO][13-03 23:34:29]: Opened new Chrome driver to https://www.facebook.com/999364434893819
# [Page Crawler][INFO][13-03 23:35:32]: Opened new Chrome driver to https://www.facebook.com/3714882738825238
# [Page Crawler][INFO][13-03 23:36:06]: Opened new Chrome driver to https://www.facebook.com/3630823483795947
# [Page Crawler][WARNING][13-03 23:36:06]: Skipping 157th post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 172, in parse
#     post = self.parse_post(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 311, in parse_post
#     visual_urls = self.get_visual_content(visual_content_div)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 402, in get_visual_content
#     video_result = get_video_url_from_source(new_chrome.page_source)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/utils/parsing.py", line 52, in get_video_url_from_source
#     video_url = re.search(r'"base_url":"([^"]+)"', source).group(1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 23:37:39]: Opened new Chrome driver to https://www.facebook.com/471055742540514
# [Page Crawler][WARNING][13-03 23:37:39]: Skipping 160th post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 172, in parse
#     post = self.parse_post(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 311, in parse_post
#     visual_urls = self.get_visual_content(visual_content_div)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 402, in get_visual_content
#     video_result = get_video_url_from_source(new_chrome.page_source)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/utils/parsing.py", line 52, in get_video_url_from_source
#     video_url = re.search(r'"base_url":"([^"]+)"', source).group(1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 23:38:06]: Opened new Chrome driver to https://www.facebook.com/1219560552810853
# [Page Crawler][WARNING][13-03 23:38:07]: Skipping 161st post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 172, in parse
#     post = self.parse_post(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 311, in parse_post
#     visual_urls = self.get_visual_content(visual_content_div)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 402, in get_visual_content
#     video_result = get_video_url_from_source(new_chrome.page_source)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/utils/parsing.py", line 52, in get_video_url_from_source
#     video_url = re.search(r'"base_url":"([^"]+)"', source).group(1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 23:38:25]: Opened new Chrome driver to https://www.facebook.com/1167737377742952
# [Page Crawler][WARNING][13-03 23:38:25]: Skipping 162nd post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 223, in parse_reel
#     reel_video_urls = get_video_url_from_source(new_chrome.page_source)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/utils/parsing.py", line 52, in get_video_url_from_source
#     video_url = re.search(r'"base_url":"([^"]+)"', source).group(1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 23:38:40]: Opened new Chrome driver to https://www.facebook.com/899907011900341
# [Page Crawler][WARNING][13-03 23:38:40]: Skipping 163rd post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 223, in parse_reel
#     reel_video_urls = get_video_url_from_source(new_chrome.page_source)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/utils/parsing.py", line 52, in get_video_url_from_source
#     video_url = re.search(r'"base_url":"([^"]+)"', source).group(1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 23:38:54]: Opened new Chrome driver to https://www.facebook.com/1173993870422350
# [Page Crawler][WARNING][13-03 23:38:54]: Skipping 164th post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 223, in parse_reel
#     reel_video_urls = get_video_url_from_source(new_chrome.page_source)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/utils/parsing.py", line 52, in get_video_url_from_source
#     video_url = re.search(r'"base_url":"([^"]+)"', source).group(1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 23:40:16]: Opened new Chrome driver to https://www.facebook.com/436565242430508
# [Page Crawler][WARNING][13-03 23:40:16]: Skipping 167th post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 161, in parse
#     post = self.parse_reel(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 223, in parse_reel
#     reel_video_urls = get_video_url_from_source(new_chrome.page_source)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/utils/parsing.py", line 52, in get_video_url_from_source
#     video_url = re.search(r'"base_url":"([^"]+)"', source).group(1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 23:40:45]: Opened new Chrome driver to https://www.facebook.com/736620771708678
# [Page Crawler][WARNING][13-03 23:40:45]: Skipping 168th post: AttributeError: 'NoneType' object has no attribute 'group'
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 172, in parse
#     post = self.parse_post(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 311, in parse_post
#     visual_urls = self.get_visual_content(visual_content_div)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 402, in get_visual_content
#     video_result = get_video_url_from_source(new_chrome.page_source)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/utils/parsing.py", line 52, in get_video_url_from_source
#     video_url = re.search(r'"base_url":"([^"]+)"', source).group(1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
#
# [Page Crawler][INFO][13-03 23:43:33]: Opened new Chrome driver to https://www.facebook.com/811688520836033
# [Page Crawler][INFO][13-03 23:44:37]: Opened new Chrome driver to https://www.facebook.com/991905919203549
# [Page Crawler][INFO][13-03 23:48:57]: Opened new Chrome driver to https://www.facebook.com/801135948155896
# [Page Crawler][INFO][13-03 23:50:41]: Opened new Chrome driver to https://www.facebook.com/1169443171098793
# [Page Crawler][INFO][13-03 23:51:39]: Opened new Chrome driver to https://www.facebook.com/1447110505901414
# [Page Crawler][INFO][13-03 23:54:27]: Opened new Chrome driver to https://www.facebook.com/814707334041293
# [Page Crawler][INFO][13-03 23:54:55]: Opened new Chrome driver to https://www.facebook.com/1585290498971924
# [Page Crawler][INFO][13-03 23:57:08]: Opened new Chrome driver to https://www.facebook.com/1215763516074287
# [Page Crawler][WARNING][14-03 00:05:24]: Skipping 199th post: NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"(//div[@role='dialog'])[last()]//div[@class='xu06os2 x1ok221b'][last()]//a"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5fd7f37bb46a <unknown>
# #1 0x5fd7f3274ed0 <unknown>
# #2 0x5fd7f32c6935 <unknown>
# #3 0x5fd7f32c6b61 <unknown>
# #4 0x5fd7f33159d4 <unknown>
# #5 0x5fd7f32ec88d <unknown>
# #6 0x5fd7f3312ceb <unknown>
# #7 0x5fd7f32ec633 <unknown>
# #8 0x5fd7f32b81be <unknown>
# #9 0x5fd7f32b9981 <unknown>
# #10 0x5fd7f378186b <unknown>
# #11 0x5fd7f378573c <unknown>
# #12 0x5fd7f3768f12 <unknown>
# #13 0x5fd7f37862b4 <unknown>
# #14 0x5fd7f374d0af <unknown>
# #15 0x5fd7f37a9ad8 <unknown>
# #16 0x5fd7f37a9cb6 <unknown>
# #17 0x5fd7f37ba2e6 <unknown>
# #18 0x770bacc9caa4 <unknown>
# #19 0x770bacd29c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 172, in parse
#     post = self.parse_post(post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 311, in parse_post
#     visual_urls = self.get_visual_content(visual_content_div)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 396, in get_visual_content
#     post_id = self.get_post_id_from_dialog()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Downloads/facebook-crawler-framework-main/crawlers/page_crawler/crawler.py", line 439, in get_post_id_from_dialog
#     post_id = self.chrome.find_element(By.XPATH, "(//div[@role='dialog'])[last()]//div[@class='xu06os2 x1ok221b'][last()]//a")
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 1244, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"(//div[@role='dialog'])[last()]//div[@class='xu06os2 x1ok221b'][last()]//a"}
#   (Session info: chrome=134.0.6998.88)
# Stacktrace:
# #0 0x5fd7f37bb46a <unknown>
# #1 0x5fd7f3274ed0 <unknown>
# #2 0x5fd7f32c6935 <unknown>
# #3 0x5fd7f32c6b61 <unknown>
# #4 0x5fd7f33159d4 <unknown>
# #5 0x5fd7f32ec88d <unknown>
# #6 0x5fd7f3312ceb <unknown>
# #7 0x5fd7f32ec633 <unknown>
# #8 0x5fd7f32b81be <unknown>
# #9 0x5fd7f32b9981 <unknown>
# #10 0x5fd7f378186b <unknown>
# #11 0x5fd7f378573c <unknown>
# #12 0x5fd7f3768f12 <unknown>
# #13 0x5fd7f37862b4 <unknown>
# #14 0x5fd7f374d0af <unknown>
# #15 0x5fd7f37a9ad8 <unknown>
# #16 0x5fd7f37a9cb6 <unknown>
# #17 0x5fd7f37ba2e6 <unknown>
# #18 0x770bacc9caa4 <unknown>
# #19 0x770bacd29c3c <unknown>
#
#
# RAM Usage (GB):  64%|███▏ | 9.75/15.33 [1:36:31<55:14, 594.04s/it, Scraped: 181][Page Crawler][INFO][14-03 00:05:44]: Closing driver due to no URL left in queue...
# RAM Usage (GB):  64%|███▏ | 9.75/15.33 [1:36:52<55:26, 596.12s/it, Scraped: 181]

# %% [markdown]
# ### Trong trường hợp Facebook yêu cầu đăng nhập lại
#
# Chạy cell code dưới đây, một cửa sổ Chrome sẽ hiện ra. Hãy đăng nhập Facebook bằng cửa sổ Chrome này.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from utils.cookies import Cookies

driver_service = Service("/home/ptdat/Downloads/chromedriver-linux64/chromedriver")
driver_options = webdriver.ChromeOptions()
driver_options.add_argument("--blink-settings=imagesEnabled=false")
driver_options.add_argument("--disable-notifications")
driver_options.add_argument("disable-infobars")
# driver_options.add_argument("--incognito")
cookies = Cookies("user1")

chrome = webdriver.Chrome(service=driver_service, options=driver_options)
chrome.get("https://facebook.com")
# for cookie in cookies.load():
#     chrome.add_cookie(cookie)
# chrome.get(" https://www.facebook.com/naman.benhvienthammy")

# %% [markdown]
# Sau khi hoàn thành đăng nhập (truy cập được news feed của tài khoản Facebook). Hãy chạy cell dưới đây để lưu cookies và giữ phiên đăng nhập cho những lần sau.

# %%
cookies.save(chrome.get_cookies())

# %% [markdown]
# Tại bước này có thể tắt cửa sổ Chrome đi được rùi.

# %%
from utils.parsing import get_video_url_from_source

with open("index.html", "r") as f:
    urls = get_video_url_from_source(f.read())

urls
# Out:
# {'video_url': 'https://scontent.fsgn2-10.fna.fbcdn.net/o1/v/t2/f2/m69/AQMIapfO8DZsUv9saXhfNAV_nH99_64jnQbBh5AzaeWwNdML0m_z1XmA6Z9VFgbbpSNbSRJ750MquECgEoOGWVRy.mp4?strext=1&_nc_cat=109&_nc_oc=AdiljNqEH424rSoXY0hpIOscQr_DpeM-M8i6VWvbEQl99eu0xBbDYz3PTImCHi2LRdI&_nc_sid=9ca052&_nc_ht=scontent.fsgn2-10.fna.fbcdn.net&_nc_ohc=n4QrWWkBKWsQ7kNvgGzhJ0e&efg=eyJ2ZW5jb2RlX3RhZyI6ImRhc2hfcjJhdjEtcjFnZW4ydnA5X3EyMCIsInZpZGVvX2lkIjo0MDQwOTYyMDA5NDU4MjIyLCJjbGllbnRfbmFtZSI6InVua25vd24iLCJvaWxfdXJsZ2VuX2FwcF9pZCI6MCwidXJsZ2VuX3NvdXJjZSI6Ind3dyJ9&ccb=17-1&_nc_zt=28&oh=00_AYEcz4z1W3P6iG2ytr4zbRzofjkUhyMSREqq4QsGgpLmCw&oe=67D8DB41',
#  'audio_url': 'https://scontent.fsgn2-11.fna.fbcdn.net/o1/v/t2/f2/m69/AQNzv3J4712yf4U6TrK9bmiZpqVUEaPOajiEQxe3YHrsrxHsT7CzQkyVJwut490Ne3_A4QFIx6qZR-EJ9fv8uhdz.mp4?strext=1&_nc_cat=105&_nc_oc=AdiUpcIstYmouHchNWr13KyDCQNNPoB12kCYOq4p2MdeVbVDcOZt1JSmDV5jmVYuzw0&_nc_sid=9ca052&_nc_ht=scontent.fsgn2-11.fna.fbcdn.net&_nc_ohc=fPpOyAngv4YQ7kNvgGcMUxV&efg=eyJ2ZW5jb2RlX3RhZyI6ImRhc2hfbG5faGVhYWNfdmJyM19hdWRpbyIsInZpZGVvX2lkIjo0MDQwOTYyMDA5NDU4MjIyLCJjbGllbnRfbmFtZSI6InVua25vd24iLCJvaWxfdXJsZ2VuX2FwcF9pZCI6MCwidXJsZ2VuX3NvdXJjZSI6Ind3dyJ9&ccb=17-1&_nc_zt=28&oh=00_AYFf4SFvr04kTgfD1tUB5MnLlCQAIeBKq_XBhUuM3Fngsw&oe=67D8F155'}
